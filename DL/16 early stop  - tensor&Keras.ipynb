# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
# 관련 라이브러리 임포트 
import matplotlib.font_manager as fm
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.style.use('ggplot')

# %% [markdown]
# # 과적합 방지
#
#
# - 학습 횟수 최대한 , 학습 완료시 학습종료
#
# ```
# 1. 학습횟수는 최대한
# 2. patience : 기다리는 횟수
# 3. min_delta : cost 값의 차이 ( 0.01, 0.001 )
#
# ```

# %% [markdown]
# ## tensor 방식으로 구현
# - 코드로 구현해야댐

# %%
df = pd.read_csv('data/test.csv',header=None)
df.columns = ['q1','q2','mid','final']
df.head(3)
# Out:
#    q1  q2  mid  final
# 0  73  80   75    152
# 1  93  88   93    185
# 2  89  91   90    180

# %%
df.iloc[:,-1]
# Out:
# 0     152
# 1     185
# 2     180
# 3     196
# 4     142
# 5     101
# 6     149
# 7     115
# 8     175
# 9     164
# 10    141
# 11    141
# 12    184
# 13    152
# 14    148
# 15    192
# 16    147
# 17    183
# 18    177
# 19    159
# 20    177
# 21    175
# 22    175
# 23    149
# 24    192
# Name: final, dtype: int64

# %%
df.iloc[:,[-1]]
# Out:
#     final
# 0     152
# 1     185
# 2     180
# 3     196
# 4     142
# 5     101
# 6     149
# 7     115
# 8     175
# 9     164
# 10    141
# 11    141
# 12    184
# 13    152
# 14    148
# 15    192
# 16    147
# 17    183
# 18    177
# 19    159
# 20    177
# 21    175
# 22    175
# 23    149
# 24    192

# %%
x_data = df.iloc[:,:-1].values
y_data = df.iloc[:,[-1]].values

# %%
x_data,y_data
# Out:
# (array([[ 73,  80,  75],
#         [ 93,  88,  93],
#         [ 89,  91,  90],
#         [ 96,  98, 100],
#         [ 73,  66,  70],
#         [ 53,  46,  55],
#         [ 69,  74,  77],
#         [ 47,  56,  60],
#         [ 87,  79,  90],
#         [ 79,  70,  88],
#         [ 69,  70,  73],
#         [ 70,  65,  74],
#         [ 93,  95,  91],
#         [ 79,  80,  73],
#         [ 70,  73,  78],
#         [ 93,  89,  96],
#         [ 78,  75,  68],
#         [ 81,  90,  93],
#         [ 88,  92,  86],
#         [ 78,  83,  77],
#         [ 82,  86,  90],
#         [ 86,  82,  89],
#         [ 78,  83,  85],
#         [ 76,  83,  71],
#         [ 96,  93,  95]], dtype=int64),
#  array([[152],
#         [185],
#         [180],
#         [196],
#         [142],
#         [101],
#         [149],
#         [115],
#         [175],
#         [164],
#         [141],
#         [141],
#         [184],
#         [152],
#         [148],
#         [192],
#         [147],
#         [183],
#         [177],
#         [159],
#         [177],
#         [175],
#         [175],
#         [149],
#         [192]], dtype=int64))

# %%
x = tf.constant(x_data, tf.float32)
y = tf.constant(y_data, tf.float32)

# %%
w = tf.Variable(tf.random.uniform([3,1]))# 특성데이터갯수,label개수
b = tf.Variable(tf.random.uniform([1]))# [라벨개수]

# %%
def compute_loss():
    hx = tf.matmul(x,w) + b 
    cost = tf.reduce_mean((hx-y)**2)
    
    return cost

# %%
patience = 20  
min_delta = 0.01  # (전 - 후) 값을 했을 때 이 숫자보다 작으면 조기종료 
hist_cost = [] 

pcnt = 0
optimizer = Adam(0.1)
for i in range(10000):
    optimizer.minimize(compute_loss, var_list=[w,b])  # 미분 
    c = compute_loss().numpy()
    hist_cost.append(c)

    print(i, 'cost: ',c)
    
    if i>0:
        if hist_cost[i-1] - hist_cost[i] > min_delta:
            pcnt = 0
        else:
            pcnt += 1
        if pcnt >= patience : 
            print('early stop')
            break
# Out:
# 0 cost:  156.15411
# 1 cost:  144.6863
# 2 cost:  23.253227
# 3 cost:  58.504345
# 4 cost:  110.14633
# 5 cost:  66.25777
# 6 cost:  18.786385
# 7 cost:  35.89716
# 8 cost:  69.23599
# 9 cost:  58.353462
# 10 cost:  25.446524
# 11 cost:  18.853645
# 12 cost:  39.59565
# 13 cost:  49.05338
# 14 cost:  33.29953
# 15 cost:  17.293434
# 16 cost:  21.70499
# 17 cost:  34.599655
# 18 cost:  34.03375
# 19 cost:  21.732983
# 20 cost:  16.082804
# 21 cost:  22.825396
# 22 cost:  28.65316
# 23 cost:  23.972673
# 24 cost:  16.548733
# 25 cost:  17.002628
# 26 cost:  22.413643
# 27 cost:  22.826357
# 28 cost:  17.703651
# 29 cost:  15.217151
# 30 cost:  18.140802
# 31 cost:  20.29651
# 32 cost:  17.787363
# 33 cost:  14.896362
# 34 cost:  15.859114
# 35 cost:  17.947306
# 36 cost:  17.047106
# 37 cost:  14.733865
# 38 cost:  14.723359
# 39 cost:  16.240236
# 40 cost:  16.041414
# 41 cost:  14.403871
# 42 cost:  14.081182
# 43 cost:  15.079973
# 44 cost:  15.079442
# 45 cost:  13.944562
# 46 cost:  13.617737
# 47 cost:  14.26305
# 48 cost:  14.249219
# 49 cost:  13.444416
# 50 cost:  13.217983
# 51 cost:  13.6347885
# 52 cost:  13.54323
# 53 cost:  12.960095
# 54 cost:  12.847102
# 55 cost:  13.102974
# 56 cost:  12.933388
# 57 cost:  12.516816
# 58 cost:  12.49261
# 59 cost:  12.618211
# 60 cost:  12.398416
# 61 cost:  12.120852
# 62 cost:  12.144545
# 63 cost:  12.157946
# 64 cost:  11.928051
# 65 cost:  11.766479
# 66 cost:  11.792815
# 67 cost:  11.717611
# 68 cost:  11.517586
# 69 cost:  11.439585
# 70 cost:  11.431687
# 71 cost:  11.304407
# 72 cost:  11.1599455
# 73 cost:  11.1222725
# 74 cost:  11.064901
# 75 cost:  10.928955
# 76 cost:  10.840429
# 77 cost:  10.80124
# 78 cost:  10.706276
# 79 cost:  10.59527
# 80 cost:  10.539135
# 81 cost:  10.475393
# 82 cost:  10.372079
# 83 cost:  10.29486
# 84 cost:  10.240603
# 85 cost:  10.156494
# 86 cost:  10.069912
# 87 cost:  10.011284
# 88 cost:  9.943072
# 89 cost:  9.85894
# 90 cost:  9.793116
# 91 cost:  9.73294
# 92 cost:  9.656891
# 93 cost:  9.587071
# 94 cost:  9.529
# 95 cost:  9.461379
# 96 cost:  9.39177
# 97 cost:  9.333344
# 98 cost:  9.27207
# 99 cost:  9.2055025
# 100 cost:  9.146699
# 101 cost:  9.089561
# 102 cost:  9.027172
# 103 cost:  8.968924
# 104 cost:  8.914446
# 105 cost:  8.856218
# 106 cost:  8.799565
# 107 cost:  8.747026
# 108 cost:  8.692534
# 109 cost:  8.638111
# 110 cost:  8.587369
# 111 cost:  8.53603
# 112 cost:  8.48422
# 113 cost:  8.435322
# 114 cost:  8.386742
# 115 cost:  8.337596
# 116 cost:  8.290694
# 117 cost:  8.244577
# 118 cost:  8.19808
# 119 cost:  8.15324
# 120 cost:  8.109418
# 121 cost:  8.065431
# 122 cost:  8.022715
# 123 cost:  7.9811025
# 124 cost:  7.9394875
# 125 cost:  7.8989234
# 126 cost:  7.859408
# 127 cost:  7.8200893
# 128 cost:  7.78163
# 129 cost:  7.74416
# 130 cost:  7.706998
# 131 cost:  7.670619
# 132 cost:  7.6351333
# 133 cost:  7.6000304
# 134 cost:  7.565641
# 135 cost:  7.5320888
# 136 cost:  7.498966
# 137 cost:  7.4665356
# 138 cost:  7.43483
# 139 cost:  7.403612
# 140 cost:  7.373031
# 141 cost:  7.343129
# 142 cost:  7.3137126
# 143 cost:  7.2849236
# 144 cost:  7.256748
# 145 cost:  7.229054
# 146 cost:  7.2019725
# 147 cost:  7.175467
# 148 cost:  7.1494336
# 149 cost:  7.1239796
# 150 cost:  7.099065
# 151 cost:  7.074618
# 152 cost:  7.0507164
# 153 cost:  7.0273023
# 154 cost:  7.004366
# 155 cost:  6.9819446
# 156 cost:  6.959998
# 157 cost:  6.9385033
# 158 cost:  6.91749
# 159 cost:  6.8969264
# 160 cost:  6.8767824
# 161 cost:  6.8571
# 162 cost:  6.837842
# 163 cost:  6.8190017
# 164 cost:  6.8006043
# 165 cost:  6.782567
# 166 cost:  6.764976
# 167 cost:  6.7477674
# 168 cost:  6.7309227
# 169 cost:  6.7144666
# 170 cost:  6.698393
# 171 cost:  6.682692
# 172 cost:  6.6673303
# 173 cost:  6.652329
# 174 cost:  6.637661
# 175 cost:  6.6233363
# 176 cost:  6.6093445
# 177 cost:  6.595668
# 178 cost:  6.5823283
# 179 cost:  6.5692883
# 180 cost:  6.55656
# 181 cost:  6.544126
# 182 cost:  6.531976
# 183 cost:  6.5201387
# 184 cost:  6.508556
# 185 cost:  6.497253
# 186 cost:  6.4862337
# 187 cost:  6.4754624
# 188 cost:  6.464962
# 189 cost:  6.4547057
# 190 cost:  6.444695
# 191 cost:  6.434921
# 192 cost:  6.4253798
# 193 cost:  6.416083
# 194 cost:  6.4070225
# 195 cost:  6.3981714
# 196 cost:  6.3895335
# 197 cost:  6.381101
# 198 cost:  6.3728857
# 199 cost:  6.3648705
# 200 cost:  6.3570385
# 201 cost:  6.3494153
# 202 cost:  6.341971
# 203 cost:  6.3347106
# 204 cost:  6.32763
# 205 cost:  6.320724
# 206 cost:  6.3140063
# 207 cost:  6.3074217
# 208 cost:  6.301028
# 209 cost:  6.2947826
# 210 cost:  6.2886963
# early stop

# %% [markdown]
# ##  케라스 구현
# - 모듈 사용

# %%
from tensorflow.keras.optimizers import Adam,Adagrad
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
dense  = Dense(units = 1, input_dim=3)
model = Sequential([dense])
model.compile(loss = 'mse', optimizer = Adam(0.1))
earlyStop = EarlyStopping(monitor = 'loss',min_delta=0.01, patience=20)
h = model.fit(x_data,y_data ,epochs=10000, callbacks=[earlyStop])
# Out:
# Epoch 1/10000
# 1/1 [==============================] - 0s 187ms/step - loss: 48997.1953
# Epoch 2/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 38817.8242
# Epoch 3/10000
# 1/1 [==============================] - 0s 2ms/step - loss: 29863.5742
# Epoch 4/10000
# 1/1 [==============================] - 0s 2ms/step - loss: 22147.3555
# Epoch 5/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 15668.5088
# Epoch 6/10000
# 1/1 [==============================] - 0s 2ms/step - loss: 10409.0117
# Epoch 7/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 6329.1138
# Epoch 8/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 3363.1428
# Epoch 9/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 1416.2076
# Epoch 10/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 362.8012
# Epoch 11/10000
# 1/1 [==============================] - 0s 2ms/step - loss: 48.8528
# Epoch 12/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 298.2170
# Epoch 13/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 923.8453
# Epoch 14/10000
# 1/1 [==============================] - 0s 2ms/step - loss: 1742.4564
# Epoch 15/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 2590.0034
# Epoch 16/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 3334.6738
# Epoch 17/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 3884.8369
# Epoch 18/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 4190.9019
# Epoch 19/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 4241.7837
# Epoch 20/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 4057.6968
# Epoch 21/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 3681.2307
# Epoch 22/10000
# 1/1 [==============================] - 0s 2ms/step - loss: 3168.2437
# Epoch 23/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 2579.6328
# Epoch 24/10000
# 1/1 [==============================] - 0s 2ms/step - loss: 1974.4469
# Epoch 25/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 1404.5643
# Epoch 26/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 910.9292
# Epoch 27/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 521.3038
# Epoch 28/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 249.4552
# Epoch 29/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 95.6925
# Epoch 30/10000
# 1/1 [==============================] - 0s 2ms/step - loss: 48.5942
# Epoch 31/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 87.7055
# Epoch 32/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 186.8891
# Epoch 33/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 317.9308
# Epoch 34/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 453.9731
# Epoch 35/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 572.3750
# Epoch 36/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 656.7090
# Epoch 37/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 697.7427
# Epoch 38/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 693.4073
# Epoch 39/10000
# 1/1 [==============================] - 0s 2ms/step - loss: 647.9054
# Epoch 40/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 570.1916
# Epoch 41/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 472.1009
# Epoch 42/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 366.4188
# Epoch 43/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 265.1166
# Epoch 44/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 177.9523
# Epoch 45/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 111.5477
# Epoch 46/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 68.9908
# Epoch 47/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 49.9462
# Epoch 48/10000
# 1/1 [==============================] - 0s 2ms/step - loss: 51.1931
# Epoch 49/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 67.4700
# Epoch 50/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 92.4756

# %%
# 얼리스타핑을 적용한 결과 50번만에 에포크를 멈추고 종료함.
